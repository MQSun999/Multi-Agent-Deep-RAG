# %% [markdown]
# Langchain Review

# %%
from dotenv import load_dotenv
load_dotenv("./../.env")
# Out:
# True

# %%
import os

# 在导入任何网络库之前清除代理设置
for var in [
    "HTTP_PROXY",
    "HTTPS_PROXY",
    "http_proxy",
    "https_proxy",
    "ALL_PROXY",
    "all_proxy",
]:
    os.environ.pop(var, None)

# 强制设置不代理本地地址
os.environ["NO_PROXY"] = "localhost,127.0.0.1"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = "gemini-3.1-flash-lite-preview"
llm = ChatGoogleGenerativeAI(model = model)
llm.invoke("Hi There")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': 'EjQKMgG+Pvb7FYVB8n5hGGjRelV0IX4aENohw46ezgXpLbqoll5uBupdXsgiUo35qdrBO+PX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf99f-7414-7db3-a984-3a9dedc5571e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3, 'output_tokens': 9, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
prompt = ChatPromptTemplate.from_messages([("system", "You are a helpful assistant, you talk like a kindness teacher"), ("human", "{human_message}")])

chain = prompt | llm | StrOutputParser()

# %%
human_message = "Hello, how are you!"
chain.invoke({"human_message":human_message})
# Out:
# "Hello there, my dear friend! I am doing wonderfully, thank you so much for asking. It truly warms my heart to connect with you today. \n\nHow are you feeling in this moment? Remember, no matter how your day is going, you are doing your very best, and that is something to be truly proud of. Is there anything I can help you with today, or perhaps you'd just like to share a kind thought?"

# %%
from utils import base_tools
base_tools.web_search.invoke("What is openclaw")
# Out:
# [WebSearchResult(content='# What Is OpenClaw AI in 2026? A Practical Guide for Developers - DEV Community\n\nPublished: 2026-02-24T06:17:52+00:00\nType: Non-news\n\n## Summary\n\nOpenClaw AI is a self-hosted, open-source AI agent that runs on your machine and executes real-world actions, not just text replies. The self-licensed AI agent runs as a long-lived Node.js process called the Gateway and can connect to models like Claude and GPT-4. The agent can also run shell commands, manage files, send emails, and operate from Telegram. OpenClaw supports multiple agents under one Gateway process and can also spawn agents dynamically from within conversations. It is being used for background coding, CI automation, Slack bots, and Laravel scaffolding. However, it also provides a larger attack surface than traditional chatbots and requires careful deployment.\n\n## Story\n\nWhat Is OpenClaw AI in 2026? A Practical Guide for Developers - DEV Community OpenClaw AI is a self-hosted, open-source 
# ...
